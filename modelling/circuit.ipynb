# %%
# !pip install ../../cyecca/ ../../rumoca/python -q

# %%
from cyecca.backends.casadi import CasadiBackend
import matplotlib.pyplot as plt

model = CasadiBackend.from_file("circuit.mo")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 from cyecca.backends.casadi import CasadiBackend
#       2 import matplotlib.pyplot as plt
# ----> 4 model = CasadiBackend.from_file("circuit.mo")
#
# File <@beartype(cyecca.backends.base.Backend.from_file) at 0x71c727796ac0>:51, in from_file(__beartype_get_violation, __beartype_conf, __beartype_args_name_keywordable, __beartype_object_664924992, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/ws_fixedwing/src/cyecca_notebooks/venv_ros/lib/python3.12/site-packages/cyecca/backends/base.py:162, in Backend.from_file(cls, modelica_file, **backend_kwargs)
#     159     backend = cls(model, **backend_kwargs)
#     161     # Compile the backend
# --> 162     backend.compile()
#     164     return cast(T, backend)
#     165 finally:
#     166     # Clean up temporary file
#
# File <@beartype(cyecca.backends.casadi.CasadiBackend.compile) at 0x71c72469fd80>:12, in compile(__beartype_object_10746048, __beartype_get_violation, __beartype_conf, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/ws_fixedwing/src/cyecca_notebooks/venv_ros/lib/python3.12/site-packages/cyecca/backends/casadi.py:278, in CasadiBackend.compile(self)
#     274             self.derivatives[state_name] = expr_casadi
#     276 elif eq.lhs is not None:
#     277     # Algebraic equation: var = expr
# --> 278     var_name = self._get_var_name(eq.lhs)
#     279     expr_casadi = self._convert_expr(eq.rhs)
#     280     self.algebraic[var_name] = expr_casadi
#
# File <@beartype(cyecca.backends.casadi.CasadiBackend._get_var_name) at 0x71c7246940e0>:32, in _get_var_name(__beartype_object_664928576, __beartype_get_violation, __beartype_conf, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/ws_fixedwing/src/cyecca_notebooks/venv_ros/lib/python3.12/site-packages/cyecca/backends/casadi.py:446, in CasadiBackend._get_var_name(self, expr)
#     444     return expr.name
#     445 else:
# --> 446     raise ValueError(f"Cannot extract variable name from: {expr}")
#
# ValueError: Cannot extract variable name from: (R2_n_i + L1_p_i)
