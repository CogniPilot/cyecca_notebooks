# %%
# !pip install ../../cyecca/ ../../rumoca/python -q

# %%
from cyecca.backends.casadi import CasadiBackend
import matplotlib.pyplot as plt

model = CasadiBackend.from_file("bouncing_ball.mo")

# %%
t, result = model.simulate(3.5, 0.001)
plt.plot(t, result['h'])
# Out:
# CasADi - 2025-12-01 06:09:45 WARNING("Event support is experimental") [.../casadi/core/integrator.cpp:752]
